# %%
import pandas_datareader as web
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
df = pd.read_csv('8K_diabetes.csv')

# %%
df
# Out:
#                  race  gender      age   weight admission_type_id  \
# 0           Caucasian  Female  [50-60)        ?          Elective
# 1           Caucasian  Female  [20-30)  [50-75)            Urgent
# 2           Caucasian    Male  [80-90)        ?     Not Available
# 3     AfricanAmerican  Female  [50-60)        ?         Emergency
# 4     AfricanAmerican  Female  [50-60)        ?         Emergency
# ...               ...     ...      ...      ...               ...
# 7995        Caucasian    Male  [70-80)        ?          Elective
# 7996        Caucasian  Female  [50-60)        ?            Urgent
# 7997        Caucasian    Male  [50-60)        ?         Emergency
# 7998        Caucasian    Male  [80-90)        ?            Urgent
# 7999        Caucasian  Female  [70-80)        ?          Elective
#
#                                discharge_disposition_id  \
# 0                                    Discharged to home
# 1                                    Discharged to home
# 2     Discharged/transferred to home with home healt...
# 3                                    Discharged to home
# 4                                    Discharged to home
# ...                                                 ...
# 7995                      Discharged/transferred to SNF
# 7996                                 Discharged to home
# 7997  Discharged/transferred to another short term h...
# 7998                      Discharged/transferred to SNF
# 7999  Discharged/transferred to home with home healt...
#
#                              admission_source_id  time_in_hospital payer_code  \
# 0                             Physician Referral                 1         CP
# 1                             Physician Referral                 2         UN
# 2                                            NaN                 7         MC
# 3     Transfer from another health care facility                 4         UN
# 4                                 Emergency Room                 5          ?
# ...                                          ...               ...        ...
# 7995                          Physician Referral                 8          ?
# 7996                              Emergency Room                 2         UN
# 7997                                         NaN                 1          ?
# 7998                              Emergency Room                 7         MC
# 7999                    Transfer from a hospital                 6          ?
#
#                     medical_specialty  ...  glipizide.metformin  \
# 0                       Surgery-Neuro  ...                   No
# 1                                   ?  ...                   No
# 2              Family/GeneralPractice  ...                   No
# 3                                   ?  ...                   No
# 4                          Psychiatry  ...                   No
# ...                               ...  ...                  ...
# 7995  Surgery-Cardiovascular/Thoracic  ...                   No
# 7996                 Emergency/Trauma  ...                   No
# 7997                                ?  ...                   No
# 7998                  Surgery-General  ...                   No
# 7999                 InternalMedicine  ...                   No
#
#       glimepiride.pioglitazone  metformin.rosiglitazone  \
# 0                           No                       No
# 1                           No                       No
# 2                           No                       No
# 3                           No                       No
# 4                           No                       No
# ...                        ...                      ...
# 7995                        No                       No
# 7996                        No                       No
# 7997                        No                       No
# 7998                        No                       No
# 7999                        No                       No
#
#       metformin.pioglitazone  change  diabetesMed readmitted  \
# 0                         No      No           No      False
# 1                         No      No           No      False
# 2                         No      No          Yes       True
# 3                         No      No          Yes      False
# 4                         No      Ch          Yes      False
# ...                      ...     ...          ...        ...
# 7995                      No      No          Yes      False
# 7996                      No      Ch          Yes      False
# 7997                      No      Ch          Yes      False
# 7998                      No      Ch          Yes      False
# 7999                      No      Ch          Yes       True
#
#                                             diag_1_desc  \
# 0                    Spinal stenosis in cervical region
# 1     First-degree perineal laceration, unspecified ...
# 2     Pneumococcal pneumonia [Streptococcus pneumoni...
# 3                        Cellulitis and abscess of face
# 4     Bipolar I disorder, single manic episode, unsp...
# ...                                                 ...
# 7995                           Atherosclerosis of aorta
# 7996                    Disorders of mineral metabolism
# 7997  Coronary atherosclerosis of unspecified type o...
# 7998              Congestive heart failure, unspecified
# 7999                 Care involving breathing exercises
#
#                                             diag_2_desc  \
# 0                    Spinal stenosis in cervical region
# 1     Diabetes mellitus of mother, complicating preg...
# 2                 Congestive heart failure, unspecified
# 3     Streptococcus infection in conditions classifi...
# 4     Diabetes mellitus without mention of complicat...
# ...                                                 ...
# 7995  Cerebral thrombosis without mention of cerebra...
# 7996                        Alteration of consciousness
# 7997                 Postmyocardial infarction syndrome
# 7998            Paroxysmal supraventricular tachycardia
# 7999                               Budd-chiari syndrome
#
#                                             diag_3_desc
# 0                   Effusion of joint, site unspecified
# 1                                  Sideroblastic anemia
# 2                  Hyperosmolality and/or hypernatremia
# 3     Diabetes mellitus without mention of complicat...
# 4                             Depressive type psychosis
# ...                                                 ...
# 7995            Paroxysmal supraventricular tachycardia
# 7996                    Disorders of mineral metabolism
# 7997               Hyperosmolality and/or hypernatremia
# 7998                            Endomyocardial fibrosis
# 7999        Urinary tract infection, site not specified
#
# [8000 rows x 51 columns]

# %%
y = np.array(y)[1:]

# %%
y
# Out:
# array([ 1.45999908, -3.97000122,  1.75499725,  6.92500305,  1.16500092,
#        -3.66500092,  2.51499939, -3.59999847, -2.38500214,  5.14499664,
#        -6.32499695, -1.16999817, -2.25500488,  4.89000702,  2.78499603,
#         1.91999817,  3.95500183, -1.01999664, -0.13500214, -0.80000305,
#        -1.57499695,  2.40000153, -3.32500458, -7.56499481, -0.20500183,
#        -2.43499756,  0.26499939,  3.18000031,  0.85999298, -5.53999329,
#         1.06999969, -5.18000031, -2.31999969, -2.49000168, -5.2100029 ,
#         0.82000351, -4.24000168, -0.09999847, -1.59000015,  4.80999756,
#         5.4600029 ,  1.17999649,  1.49000168, -7.75999832,  1.95999908,
#        -1.33000183,  1.95000076,  3.68000031, -4.18000031, -5.54000092,
#         0.15000153,  3.86999893, -0.00999832, -5.08000183, -1.77000046,
#        -1.55999756, -3.74000168,  4.42000198,  2.34999847,  0.54999924,
#        -2.41999817,  2.38999939, -2.18999863, -2.15000153, -5.36999893,
#        -0.59000015,  4.50999832, -1.5       , -2.79999924, -2.47999954,
#         3.68999863,  4.88999939,  1.62000275,  3.1099968 , -0.37999725,
#         3.11999893, -2.36000061,  3.47000122, -0.09000015,  2.59000015,
#         3.04999924, -1.88000107, -2.50999832, -0.25      ,  3.61999893,
#        -4.06999969, -3.77999878,  0.34999847, -2.20999908, -3.68000031,
#        -0.61999893,  2.84999847, -3.38999939,  0.13000107,  3.02999878,
#        -2.25999832, -2.81000137, -3.58000183,  1.54000092, -4.84000015,
#        -0.16999817,  4.02000046, -5.53000259])

# %%
x_mean = sum(x)/len(x)

# %%
y_mean = y.sum()/len(y)

# %%
SSxy = sum((x-x_mean)*(y-y_mean))

# %%
SSxx = sum((x-x_mean)**2)

# %%
b1 = SSxy/SSxx

# %%
b0 = y_mean-b1*x_mean

# %%
X = np.linspace(0,104)

# %%
Y = b0+b1*X

# %%
plt.plot(x,y)
plt.plot(X,Y)

# %%
i = 1/(1+np.exp(y))

# %%
plt.scatter(x,i)
